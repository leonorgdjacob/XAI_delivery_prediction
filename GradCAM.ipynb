# %% [markdown]
# Grad-CAM applied to ResNet-18 image dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
#import zipfile
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define your dataset path
FEMUR_cesarean_train = "/content/drive/MyDrive/TESE/Project/FEMUR_cesarean_train_cv1_layer4"
FEMUR_cesarean_test = "/content/drive/MyDrive/TESE/Project/FEMUR_cesarean_test_cv1_layer4"
FEMUR_vaginal_train = "/content/drive/MyDrive/TESE/Project/FEMUR_vaginal_train_cv1_layer4"
FEMUR_vaginal_test = "/content/drive/MyDrive/TESE/Project/FEMUR_vaginal_test_cv1_layer4"

HEAD_cesarean_train = "/content/drive/MyDrive/TESE/Project/HEAD_cesarean_train_cv1_layer4"
HEAD_cesarean_test = "/content/drive/MyDrive/TESE/Project/HEAD_cesarean_test_cv1_layer4"
HEAD_vaginal_train = "/content/drive/MyDrive/TESE/Project/HEAD_vaginal_train_cv1_layer4"
HEAD_vaginal_test = "/content/drive/MyDrive/TESE/Project/HEAD_vaginal_test_cv1_layer4"

ABDOMEN_cesarean_train = "/content/drive/MyDrive/TESE/Project/ABDOMEN_cesarean_train_cv1_layer4"
ABDOMEN_cesarean_test = "/content/drive/MyDrive/TESE/Project/ABDOMEN_cesarean_test_cv1_layer4"
ABDOMEN_vaginal_train = "/content/drive/MyDrive/TESE/Project/ABDOMEN_vaginal_train_cv1_layer4"
ABDOMEN_vaginal_test = "/content/drive/MyDrive/TESE/Project/ABDOMEN_vaginal_test_cv1_layer4"

# %%
# Check if directory exists
if os.path.exists(ABDOMEN_cesarean_train):
    print(f"Dataset found at {ABDOMEN_cesarean_train}")
    print("Listing files in dataset directory:\n")
    print(os.listdir(ABDOMEN_cesarean_train))  # List files and folders
else:
    print(f"Dataset not found at {ABDOMEN_cesarean_train}. Check the path!")
# Out:
# Dataset found at /content/drive/MyDrive/TESE/Project/ABDOMEN_cesarean_train_cv1_layer4
# Listing files in dataset directory:
#
# ['PU19017940_abdomen1_557.png', 'PU18020643_abdomen1_698.png', 'PU19025956_abdomen1_719.png', 'PU17013243_abdomen1_301.png', 'PU16011929_abdomen1_258.png', 'PU9125486_abdomen1_429.png', 'PU19900168_abdomen1_82.png', 'PU20025956_abdomen1_380.png', 'PU1003661_abdomen1_6.png', 'PU9322841_abdomen1_781.png', 'PU15042514_abdomen1_665.png', 'PU18020038_abdomen1_311.png', 'PU9155326_abdomen1_242.png', 'PU12009721_abdomen1_286.png', 'PU19920963_abdomen1_358.png', 'PU9014454_abdomen1_207.png', 'PU9101141_abdomen1_756.png', 'PU19013025_abdomen1_338.png', 'PU15001131_abdomen1_487.png', 'PU19093249_abdomen1_322.png', 'PU19318732_abdomen1_355.png', 'PU19428417_abdomen1_346.png', 'PU19004518_abdomen1_334.png', 'PU9210449_abdomen1_457.png', 'PU20039248_abdomen1_386.png', 'PU12023917_abdomen1_18.png', 'PU21001673_abdomen1_392.png', 'PU99005641_abdomen1_464.png', 'PU18020432_abdomen1_694.png', 'PU19372367_abdomen1_733.png', 'PU19072745_abdomen1_43.png', 'PU9148482_abdomen1_441.png', 'PU19924151_abdomen1_533.png', 'PU8004704_abdomen1_205.png', 'PU19087331_abdomen1_319.png', 'PU19029525_abdomen1_722.png', 'PU19339114_abdomen1_357.png', 'PU9192975_abdomen1_249.png', 'PU21008568_abdomen1_395.png', 'PU11011732_abdomen1_13.png', 'PU19023224_abdomen1_289.png', 'PU19008327_abdomen1_336.png', 'PU9175486_abdomen1_449.png', 'PU7002074_abdomen1_392.png', 'PU18018498_abdomen1_520.png', 'PU21006222_abdomen1_103.png', 'PU19095022_abdomen1_328.png', 'PU1003212_abdomen1_282.png', 'PU9155829_abdomen1_243.png', 'PU17022472_abdomen1_669.png', 'PU9102928_abdomen1_411.png', 'PU10022616_abdomen1_211.png', 'PU9020088_abdomen1_212.png', 'PU18093014_abdomen1_96.png', 'PU16001996_abdomen1_57.png', 'PU10014002_abdomen1_3.png', 'PU9328179_abdomen1_621.png', 'PU18022125_abdomen1_266.png', 'PU2000870_abdomen1_743.png', 'PU20044781_abdomen1_102.png', 'PU19759372_abdomen1_788.png', 'PU10002107_abdomen1_276.png', 'PU19558372_abdomen1_68.png', 'PU19022068_abdomen1_714.png', 'PU19002874_abdomen1_705.png', 'PU18057908_abdomen1_278.png', 'PU19740326_abdomen1_350.png', 'PU10011068_abdomen1_467.png', 'PU9006259_abdomen1_755.png', 'PU19007484_abdomen1_542.png', 'PU19874442_abdomen1_834.png', 'PU9199562_abdomen1_780.png', 'PU19020671_abdomen1_712.png', 'PU19010814_abdomen1_337 (1).png', 'PU19103260_abdomen1_329.png', 'PU19010814_abdomen1_337.png', 'PU14002418_abdomen1_234.png', 'PU13022125_abdomen1_231.png', 'PU18010924_abdomen1_514.png', 'PU9190880_abdomen1_452.png', 'PU2004178_abdomen1_101.png', 'PU9164324_abdomen1_472.png', 'PU19006873_abdomen1_40 (1).png', 'PU11005271_abdomen1_215.png', 'PU97014868_abdomen1_513.png', 'PU19262115_abdomen1_50.png', 'PU11004693_abdomen1_640.png', 'PU20023577_abdomen1_132.png', 'PU17019799_abdomen1_304.png', 'PU20010471_abdomen1_836.png', 'PU9144176_abdomen1_241.png', 'PU9387761_abdomen1_626.png', 'PU19006873_abdomen1_40.png', 'PU9160523_abdomen1_0.png', 'PU17009119_abdomen1_68.png', 'PU3002681_abdomen1_551.png', 'PU19026687_abdomen1_565.png', 'PU17022392_abdomen1_307.png', 'PU19057240_abdomen1_113.png', 'PU9122261_abdomen1_768.png', 'PU9178397_abdomen1_176.png', 'PU9119736_abdomen1_135.png', 'PU9111006_abdomen1_762.png', 'PU19892821_abdomen1_377.png', 'PU16022515_abdomen1_505.png', 'PU9156009_abdomen1_161.png', 'PU16007426_abdomen1_254.png', 'PU20001889_abdomen1_569.png', 'PU9158766_abdomen1_865.png', 'PU20010600_abdomen1_131.png', 'PU99011179_abdomen1_632.png', 'PU19876242_abdomen1_373.png', 'PU19001718_abdomen1_330.png', 'PU18014821_abdomen1_683.png', 'PU19028420_abdomen1_345.png', 'PU20027451_abdomen1_750.png', 'PU10025847_abdomen1_806.png', 'PU14027930_abdomen1_244.png', 'PU15042402_abdomen1_816.png', 'PU14013664_abdomen1_482.png', 'PU9163002_abdomen1_778.png', 'PU9122053_abdomen1_423.png', 'PU9359004_abdomen1_783.png', 'PU20032983_abdomen1_384.png', 'PU11018785_abdomen1_16.png', 'PU20042025_abdomen1_142.png', 'PU9191229_abdomen1_489.png', 'PU9106610_abdomen1_421.png', 'PU13019208_abdomen1_23.png', 'PU19186554_abdomen1_336.png', 'PU9332638_abdomen ...

# %%
# # Define Dataset Path and Extract ZIP File ---
# zip_path = "/content/drive/MyDrive/TESE/Project/image-dataset.zip"  # Update this with your dataset location
# extract_path = "/content/selected_images/" #content is default working directory in colab
# target_folder = "dataset_images_cv_1/Abdomen_/test/Cesarean Birth/"  # Folder inside the ZIP you want to extract (modify as needed)


# # Create extraction directory if it doesnt exist
# os.makedirs(extract_path, exist_ok=True)

# # Open ZIP
# with zipfile.ZipFile(zip_path, 'r') as zip_rep: #opens zip in read mode 'r'
#   #extract target folder files
#   for file in zip_rep.namelist():
#     if file.startswith(target_folder)and file.lower().endswith(('.jpg', '.png')):
#       zip_rep.extract(file, extract_path)

# print(f"Extracted all files from '{target_folder}' to '{extract_path}'")

# %%
import torch
import torch.nn as nn
import cv2
import numpy as np
import matplotlib.pyplot as plt
from torchvision import transforms, models
import torchvision.utils as vutils
import torchvision.transforms.functional as TF
from PIL import Image

# %%
# Define device
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# next cell: recreate architecture to match the one used for training before loading the weights

# %%
# Load base ResNet-18 model
model = models.resnet18(weights=None)

# Modify first convolutional layer for grayscale input
model.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

# Modify the final fully connected layer for binary classification
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

# Move the model to the correct device (CPU or GPU)
model.to(device)

# Load the saved model weights
model_path = "/content/drive/MyDrive/TESE/Project/best-model_cv1_abdomen_resnet18.pth"
model.load_state_dict(torch.load(model_path, map_location=device))

# Set the model to evaluation mode (important for inference)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = None
        self.gradients = None
        self.activations = None
        self.hook_layers(target_layer)

    def hook_layers(self, target_layer): # FP and BP
        def backward_hook(module, grad_input, grad_output):
            self.gradients = grad_output[0] # activations' gradients during backward [1, 512, 3, 3]
        def forward_hook(module, input, output):
            self.activations = output # layer4 activation during forward [1, 512, 3, 3]


        # Find the layer by name
        for name, module in self.model.named_modules():
            if name == target_layer:
                self.target_layer = module
                module.register_forward_hook(forward_hook)
                module.register_full_backward_hook(backward_hook)
                break

        if self.target_layer is None:
            raise ValueError(f"Layer {target_layer} not found in model.")


    def generate(self, input_tensor, class_indices=None):
        output = self.model(input_tensor) # forward pass
        if class_indices is None: # if target class is not specified, it uses class prediction (argmax)
            class_indices = torch.argmax(output, dim=1)

        self.model.zero_grad() # Clear any previous gradients
        one_hot = torch.zeros_like(output, device=device)
        for i, class_idx in enumerate(class_indices):
            one_hot[i, class_idx] = 1

        output.backward(gradient=one_hot) #
        self.model.zero_grad() # Ensure no gradients persist after Grad-CAM computation


         # Compute the Grad-CAM heatmap
        weights = torch.nn.functional.adaptive_avg_pool2d(self.gradients, 1) # avgpool - reduces spatial resolution for output_size=1 -> [1, 512, 1, 1]
        cam = torch.sum(weights * self.activations, dim=1, keepdim=True) # cam operation - [1,1,3,3]
        cam = torch.relu(cam)

        # Normalize Grad-CAM heatmap
        cam = cam / (cam.max(dim=2, keepdim=True)[0].max(dim=3, keepdim=True)[0] + 1e-6)
        return cam.cpu().detach().numpy(), class_indices.cpu().numpy()

# %%
# Define Image Transformations (Ensure grayscale input and correct format)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((80, 80)),  # Match model's input size
    transforms.ToTensor(),
])

# %%
# === Ground Truth Extractor ===
def get_ground_truth_label(img_name, input_folder):
    if "cesarean" in input_folder.lower():
        return "Cesarean Birth"
    elif "vaginal" in input_folder.lower():
        return "Vaginal Birth"
    elif "Cesarean" in img_name:
        return "Cesarean Birth"
    elif "Vaginal" in img_name:
        return "Vaginal Birth"
    else:
        print(f"Warning: Could not determine ground truth for {img_name}. Assuming 'Cesarean Birth'.")
        return "Cesarean Birth"

# %%
# === Prediction Frame ===
def add_colored_frame(image, color, thickness=20):
    height, width = image.shape[:2]
    cv2.rectangle(image, (0, 0), (width - 1, height - 1), color, thickness)
    return image

# %%
# === Heatmap Overlay ===
def overlay_heatmap(original_image, heatmap): #heatmap w\ size [1,3,3]
    heatmap = cv2.resize(heatmap[0], (original_image.shape[1], original_image.shape[0])) #heatmap size from [3,3] to [80,80]
    heatmap = np.uint8(255 * heatmap) #adapt to image format needed for color mapping
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET) #apply color map
    original_image = cv2.cvtColor(original_image, cv2.COLOR_GRAY2BGR) # Convert grayscale to 3-channel image
    overlay = cv2.addWeighted(original_image, 0.6, heatmap, 0.4, 0) #blend - 60% of grayscale image , 40% for colored heatmap
    return overlay

# %%
def apply_gradcam_and_save(model, input_folder, output_folder, grid_image_size=(80, 80)):
    os.makedirs(output_folder, exist_ok=True)
    grad_cam = GradCAM(model, 'layer4')

    image_list = []
    image_names = []
    original_images = []
    correct_heatmaps = []

    misclassified_tensors = []
    correctly_classified_tensors = []

    class_names = ["Cesarean Birth", "Vaginal Birth"]

    for img_name in os.listdir(input_folder):
        if not img_name.lower().endswith((".png", ".jpg", ".jpeg")):
            continue

        img_path = os.path.join(input_folder, img_name)

        # Load image
        image = Image.open(img_path)

        # Keep a copy of the original grayscale version for visualization
        original_np = np.array(image.convert("L"))
        original_images.append(original_np)

        # Transform image to tensor: [1, 80, 80] → unsqueeze → [1, 1, 80, 80]
        input_tensor = transform(image).unsqueeze(0).to(device)

        # Grad-CAM
        cam_heatmaps, predicted_classes = grad_cam.generate(input_tensor)
        prediction = predicted_classes[0]
        predicted_label = class_names[prediction]


        # === Ground truth from folder name ===
        ground_truth_label = get_ground_truth_label(img_name, input_folder)
        ground_truth_class = class_names.index(ground_truth_label)

        # === Choose frame color ===
        frame_color = (0, 255, 0)  # green
        if prediction != ground_truth_class:
            frame_color = (0, 0, 255)  # red

        # === Overlay and save ===
        overlay = overlay_heatmap(original_np, cam_heatmaps[0]) # cam shape = [1,3,3]
        overlay_with_frame = add_colored_frame(overlay, frame_color, thickness=20)

        save_path = os.path.join(output_folder, f"heatmap_{predicted_label}_{img_name}")
        cv2.imwrite(save_path, overlay_with_frame)
        print(f"Saved: {save_path} ; Predicted: {predicted_label}")

        # === Add to grid tensor ===
        overlay_rgb = cv2.cvtColor(overlay_with_frame, cv2.COLOR_BGR2RGB) #converts to rgb
        overlay_pil = Image.fromarray(overlay_rgb).resize(grid_image_size) # downsizes the image to fit the grid
        tensor_for_grid = TF.to_tensor(overlay_pil) #converts into a pytorch tensor [3,H,W] and normalizes pixel values

        if prediction == ground_truth_class:
            correctly_classified_tensors.append(tensor_for_grid)
            correct_heatmaps.append(cam_heatmaps[0][0])  # 2D spatial heatmap , cam shape = [3,3]
        else:
            misclassified_tensors.append(tensor_for_grid)

    # === CREATE GRID ===
    final_sorted_grid = misclassified_tensors + correctly_classified_tensors
    if final_sorted_grid:
        grid = vutils.make_grid(final_sorted_grid, nrow=20, padding=5, normalize=True)
        grid_path = os.path.join(output_folder, "grid_overlay_ordered.jpg")
        vutils.save_image(grid, grid_path)
        print(f"Grid saved at: {grid_path}")

    # === OVERLAP ONLY CORRECT HEATMAPS ===
    if correct_heatmaps: #list of NumPy arrays (raw grad-cam maps before resizing or coloring), each w\ shape [3, 3]
        mean_heatmap = np.mean(np.stack(correct_heatmaps), axis=0) # turns list of N heatmaps into 3D array w\ shape [N, 3, 3]
        mean_heatmap -= mean_heatmap.min() # subtracts the minimum value from every pixel so the lowest value is 0
        mean_heatmap /= (mean_heatmap.max() + 1e-8) # divides every pixel by the new maximum value (normalize) ; adds 1e-8 to ensure it wont be divided by 0
        heatmap_uint8 = np.uint8(255 * mean_heatmap) # Converts [0.0 – 1.0] → [0 – 255] format needed for OpenCV
        heatmap_colored = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET) # assigns color to the values

        # Resize to match original image size
        h, w = original_images[0].shape[:2]
        heatmap_resized_blocky = cv2.resize(heatmap_colored, (w, h), interpolation=cv2.INTER_NEAREST) #INTER_CUBIC for smoother transitions ; INTER_NEAREST for blocky look
        heatmap_resized_smooth = cv2.resize(heatmap_colored, (w, h), interpolation=cv2.INTER_CUBIC)


        mean_path_blocky = os.path.join(output_folder, "correct_mean_heatmap_blocky.jpg")
        cv2.imwrite(mean_path_blocky, heatmap_resized_blocky)
        print(f"Mean heatmap (correct only) saved at: {mean_path_blocky}")

        mean_path_smooth = os.path.join(output_folder, "correct_mean_heatmap_smooth.jpg")
        cv2.imwrite(mean_path_smooth, heatmap_resized_smooth)
        print(f"Mean heatmap (correct only) saved at: {mean_path_smooth}")


    return correct_heatmaps, original_images

# %%
# Define paths
input_folder = ABDOMEN_vaginal_train
output_folder = "/content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4"
# MUDAR NOME DO GRID

# Run the Grad-CAM processing and save grid
all_heatmaps, original_images = apply_gradcam_and_save(model, input_folder, output_folder)
# Out:
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14014150_abdomen1_240.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9158383_abdomen1_163.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU4005868_abdomen1_402.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19013289_abdomen1_340.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20033640_abdomen1_839.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16026210_abdomen1_63.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19036569_abdomen1_313.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9391673_abdomen1_506.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9105775_abdomen1_420.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18014562_abdomen1_682.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21022730_abdomen1_105.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU95009725_abdomen1_553.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU3010735_abdomen1_399.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU5709_abdomen1_189.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9116918_abdomen1_129.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU12005094_abdomen1_525.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9021739_abdomen1_588.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19016404_abdomen1_556.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19008690_abdomen1_545.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18024716_abdomen1_83.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19003866_abdomen1_331.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9101768_abdomen1_117.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19264301_abdomen1_730.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14011083_abdomen1_659.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15044788_abdomen1_497.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9127210_abdomen1_603.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9120485_abdomen1_430.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9102853_abdomen1_408.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9122397_abdomen1_431.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19000081_abdomen1_280.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18059385_abdomen1_94.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14025942_abdomen1_242.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9125040_abdomen1_426.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21010541_abdomen1_844.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9113502_abdomen1_424.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9378436_abdomen1_190.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19023811_abdomen1_290.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19361549_abdomen1_731.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU17024105_abdomen1_821.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9150298_abdomen1_443.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU12024821_abdomen1_645.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU97017544_abdomen1_266.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU4012553_abdomen1_176.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9112441_abdomen1_419.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10010378_abdomen1_636.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9179294_abdomen1_481.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9186514_abdomen1_484.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13010108_abdomen1_21.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU97017462_abdomen1_265.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15044432_abdomen1_29.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11015461_abdomen1_283.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU6011079_abdomen1_389.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20041408_abdomen1_100.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9135947_abdomen1_146.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9345351_abdomen1_503.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9195417_abdomen1_542.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9214316_abdomen1_616.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18027890_abdomen1_271.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU8010528_abdomen1_401.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20003578_abdomen1_87.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU5007917_abdomen1_557.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9140786_abdomen1_434.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU98001875_abdomen1_515.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9206660_abdomen1_495.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11019271_abdomen1_284.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18014441_abdomen1_679.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14000225_abdomen1_656.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19655061_abdomen1_366.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11023244_abdomen1_11.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15052143_abdomen1_666.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9113806_abdomen1_0.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21010985_abdomen1_158.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13000612_abdomen1_646.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18053577_abdomen1_92.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU17010966_abdomen1_262.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19003589_abdomen1_538.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9128899_abdomen1_435.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9155422_abdomen1_460.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9115676_abdomen1_222.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19005910_abdomen1_540.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14000036_abdomen1_34.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19011455_abdomen1_550.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9124525_abdomen1_425.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU4003256_abdomen1_380.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14029674_abdomen1_290.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU97018761_abdomen1_268.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18007593_abdomen1_675.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU2001326_abdomen1_571.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9178681_abdomen1_614.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20000873_abdomen1_86.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9121074_abdomen1_225.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18034454_abdomen1_273.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18028377_abdomen1_328.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9123217_abdomen1_137.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19235064_abdomen1_353.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13012884_abdomen1_32.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18024025_abdomen1_321.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18028277_abdomen1_326.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20009228_abdomen1_362.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9143145_abdomen1_237.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20041529_abdomen1_140.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19201691_abdomen1_48.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19031646_abdomen1_105.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11018741_abdomen1_807.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19505995_abdomen1_735.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9121929_abdomen1_422.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9213106_abdomen1_524.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20042278_abdomen1_389.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19022924_abdomen1_563.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16022034_abdomen1_31.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9019522_abdomen1_210.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU7005994_abdomen1_580.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20042914_abdomen1_390.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10025107_abdomen1_805.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15044789_abdomen1_54.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20006900_abdomen1_90.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19568189_abdomen1_71.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19377227_abdomen1_359.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9131040_abdomen1_234.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9388130_abdomen1_6.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19034343_abdomen1_106.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU3473_abdomen1_110.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15036363_abdomen1_248.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19032886_abdomen1_723.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15052494_abdomen1_528.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18017741_abdomen1_687.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16009692_abdomen1_529.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19010709_abdomen1_548.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11001994_abdomen1_471.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9210236_abdomen1_187.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9366599_abdomen1_624.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19031538_abdomen1_304.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19347716_abdomen1_118.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU2015238_abdomen1_152.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9123969_abdomen1_769.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14022997_abdomen1_660.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU97008513_abdomen1_554.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16001123_abdomen1_249.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU8004039_abdomen1_204.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18024737_abdomen1_268.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19090488_abdomen1_825.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9225811_abdomen1_189.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9102126_abdomen1_214.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18021586_abdomen1_526.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20039073_abdomen1_385.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18009559_abdomen1_76.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19185786_abdomen1_725.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11011922_abdomen1_14.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU98007875_abdomen1_556.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9184886_abdomen1_868.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18020313_abdomen1_693.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18029757_abdomen1_533.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15031847_abdomen1_663.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU1017071_abdomen1_470.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9014161_abdomen1_586.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18125400_abdomen1_100.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9381492_abdomen1_504.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19030109_abdomen1_568.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19660865_abdomen1_739.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9118476_abdomen1_133.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18029810_abdomen1_272.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10012122_abdomen1_0.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18027934_abdomen1_322.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19497517_abdomen1_123.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9183838_abdomen1_246.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19028035_abdomen1_298.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14011979_abdomen1_38.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18020113_abdomen1_314.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU5005250_abdomen1_385.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10016707_abdomen1_4.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19026447_abdomen1_104.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19926370_abdomen1_379.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19021903_abdomen1_713.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU3010927_abdomen1_167.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9207552_abdomen1_455.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13009373_abdomen1_31.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU4015408_abdomen1_112.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19105461_abdomen1_45.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13019253_abdomen1_478.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19909090_abdomen1_125.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU2013893_abdomen1_371.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18020651_abdomen1_264.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18025298_abdomen1_530.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18009863_abdomen1_513.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20035447_abdomen1_841.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20021780_abdomen1_364.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19330878_abdomen1_57.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19313309_abdomen1_54.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9215473_abdomen1_617.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10012069_abdomen1_207.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18000400_abdomen1_37.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9005854_abdomen1_404.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10004004_abdomen1_0.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9188877_abdomen1_182.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19010278_abdomen1_285.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9123582_abdomen1_139.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21017441_abdomen1_373.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9380363_abdomen1_625.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9110584_abdomen1_416.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9176559_abdomen1_478.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9138233_abdomen1_149.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15024410_abdomen1_815.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU12002875_abdomen1_285.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21004561_abdomen1_155.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9132981_abdomen1_606.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18051836_abdomen1_276.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU2003520_abdomen1_367.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19205574_abdomen1_727.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9008546_abdomen1_584.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9178676_abdomen1_480.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11011375_abdomen1_641.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18024226_abdomen1_528.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU6001784_abdomen1_113.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9338271_abdomen1_257.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU20013997_abdomen1_93.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19028838_abdomen1_721.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9147483_abdomen1_772.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19023479_abdomen1_716.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19189853_abdomen1_115.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10429_abdomen1_9.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18020527_abdomen1_524.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19011271_abdomen1_549.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9117438_abdomen1_131.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19024067_abdomen1_292.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19006214_abdomen1_707.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9135114_abdomen1_608.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU2010762_abdomen1_149.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9102076_abdomen1_589.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19357178_abdomen1_358.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19025559_abdomen1_296.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18011023_abdomen1_515.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9189288_abdomen1_487.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16011374_abdomen1_255.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9153943_abdomen1_445.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18018356_abdomen1_81.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9168761_abdomen1_245.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19223079_abdomen1_5.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18026891_abdomen1_86.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19478232_abdomen1_65.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU6004343_abdomen1_192.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19021995_abdomen1_288.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11016133_abdomen1_642.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU6009795_abdomen1_577.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19021703_abdomen1_561.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13017912_abdomen1_22.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU17018177_abdomen1_34.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU7003482_abdomen1_393.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9121308_abdomen1_597.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9105590_abdomen1_415.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9106149_abdomen1_590.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18026944_abdomen1_532.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19094617_abdomen1_326.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14002778_abdomen1_236.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19640974_abdomen1_365.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19022759_abdomen1_715.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19017827_abdomen1_710.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19079854_abdomen1_317.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU6005749_abdomen1_850.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9125394_abdomen1_427.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9152130_abdomen1_158.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU17023684_abdomen1_70.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU99012515_abdomen1_633.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9177573_abdomen1_541.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU10133_abdomen1_8.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14004343_abdomen1_239.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9102106_abdomen1_757.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19033779_abdomen1_306.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14030612_abdomen1_812.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU18023872_abdomen1_318.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU7002891_abdomen1_197.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU12020293_abdomen1_221.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9107435_abdomen1_759.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16000751_abdomen1_56.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9118931_abdomen1_765.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9176768_abdomen1_173.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU12018290_abdomen1_17.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9346762_abdomen1_871.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU11003774_abdomen1_10.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9154576_abdomen1_160.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU21034582_abdomen1_163.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9397338_abdomen1_543.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15001514_abdomen1_814.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9107807_abdomen1_413.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9200283_abdomen1_184.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19225337_abdomen1_352.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9214144_abdomen1_496.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU16018707_abdomen1_30.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19000089_abdomen1_536.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9330652_abdomen1_870.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU14028320_abdomen1_49.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9313454_abdomen1_461.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU15052145_abdomen1_819.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9124144_abdomen1_230.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9154570_abdomen1_457.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU13003334_abdomen1_647.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19035185_abdomen1_107.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU19906049_abdomen1_378.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU97024436_abdomen1_271.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU9122770_abdomen1_226.png ; Predicted: Vaginal Birth
# Saved: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/heatmap_Vaginal Birth_PU7010157_abdomen1_853.png ; Predicted: Vaginal Birth
# Grid saved at: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/grid_overlay_ordered.jpg
# Mean heatmap (correct only) saved at: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/correct_mean_heatmap_blocky.jpg
# Mean heatmap (correct only) saved at: /content/drive/MyDrive/TESE/Project/X_ABDOMEN_vaginal_train_cv1_layer4/correct_mean_heatmap_smooth.jpg
