# %%
import os
import torch
import torch.nn as nn
import cv2
import numpy as np
from torchvision import transforms, models
import torchvision.utils as vutils
import torchvision.transforms.functional as TF
from PIL import Image
from pytorch_grad_cam import GradCAM, GradCAMPlusPlus, HiResCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

# %%
# === Define device ===
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# === RESNET18 architecture recreation ===
def load_resnet18_model(model_path, num_classes=2, device=torch.device("cpu")):
    # Load base ResNet-18 model
    model = models.resnet18(weights=None)
    # Modify first convolutional layer for grayscale input
    model.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
    # Modify the final fully connected layer for binary classification
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 2) 
    # Move the model to the correct device (CPU or GPU)
    model.to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    # Set the model to evaluation mode (important for inference)
    model.eval()
    return model

# %%
def load_densenet169_model(model_path, num_classes=2, device=torch.device("cpu")):
    # Load base DenseNet-169 model
    model = models.densenet169(weights=None)
    # Modify first convolutional layer for grayscale input
    model.features.conv0 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
    # Modify the final classifier for binary classification
    num_ftrs = model.classifier.in_features
    model.classifier = nn.Linear(num_ftrs, 2) 
    # Move the model to the correct device (CPU or GPU)
    model.to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    # Set the model to evaluation mode (important for inference)
    model.eval()
    return model

# %%
# === Define Image Transformations === (Ensure grayscale input and correct format) ************
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
    transforms.Resize((80,80)),  # Match model's input size
    transforms.ToTensor(),
])

# %%
# === Extract Ground Truth from folder path ===
def get_ground_truth(img_name, folder):
    # Combine the folder path and image name for a comprehensive check
    full_path = os.path.join(folder, img_name)
    
    # Check for the ground truth in a case-insensitive way
    if "cesarean" in full_path.lower():
        return "Cesarean Birth"
    elif "vaginal" in full_path.lower():
        return "Vaginal Birth"
    else:
        print(f"Warning: Could not determine ground truth for {full_path}. Assuming 'Cesarean Birth'.")
        ground_truth = "Cesarean Birth"

    # Print the ground truth for each image
    #print(f"[Ground Truth] Image: {img_name} | Path: {full_path} | Picked: {ground_truth}")
    return ground_truth

# %%
# === Prediction Frame ===
def add_colored_frame(image, color, thickness=20):
    height, width = image.shape[:2]
    cv2.rectangle(image, (0, 0), (width - 1, height - 1), color, thickness)
    return image

# %%
# === Heatmap Overlay ===
def overlay_heatmap(original_image, heatmap): #heatmap w\ size [1,3,3]
    heatmap = cv2.resize(heatmap[0], (original_image.shape[1], original_image.shape[0])) #heatmap size from [3,3] to [80,80]
    heatmap = np.uint8(255 * heatmap) #adapt to image format needed for color mapping
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET) #apply color map

    if len(original_image.shape) == 2 or original_image.shape[2] == 1:
        original_image = cv2.cvtColor(original_image, cv2.COLOR_GRAY2BGR)

    #original_image = cv2.cvtColor(original_image, cv2.COLOR_GRAY2BGR) # Convert grayscale to 3-channel image
    overlay = cv2.addWeighted(original_image, 0.6, heatmap, 0.4, 0) #blend - 60% of grayscale image , 40% for colored heatmap
    return overlay

# %%
def apply_gradcam_and_save(model, input_folder, output_folder, grid_image_size=(80, 80)):
    os.makedirs(output_folder, exist_ok=True)

    target_layers = [model.features.denseblock3.denselayer24]  #layer4[-1] for ResNet-18 #features.denseblock3.denselayer24 for DenseNet-169

    original_images = []
    correct_heatmaps = []
    incorrect_heatmaps = []
    misclassified_tensors = []
    correctly_classified_tensors = []

    class_names = ["Cesarean Birth", "Vaginal Birth"]

    for img_name in os.listdir(input_folder):
        if not img_name.lower().endswith((".png", ".jpg", ".jpeg")):
            continue

        img_path = os.path.join(input_folder, img_name)
        image = Image.open(img_path).convert('L')
        input_tensor = transform(image).unsqueeze(0).to(device)
        resized_image = transforms.Resize((80, 80))(image)
        original_np = np.array(resized_image)
        original_images.append(original_np)

        # Previsão para obter classe
        with torch.no_grad():
            output = model(input_tensor)
            prediction = output.argmax(dim=1).item()

        # Grad-CAM
        with GradCAMPlusPlus(model=model, target_layers=target_layers) as cam:   #use_cuda=torch.cuda.is_available()
            targets = [ClassifierOutputTarget(prediction)]
            grayscale_cam = cam(input_tensor=input_tensor, targets=targets)[0]  # [H, W]
        
        # Access raw activations (before interpolation)
        raw_activations = cam.activations_and_grads.activations[-1]  # shape: [B, C, H, W]
        print("RAW FEATURE MAP SHAPE:", raw_activations.shape)  # For example: torch.Size([1, 1664, 5, 5])

        # Just spatial resolution (pre-Grad-CAM aggregation)
        h_raw, w_raw = raw_activations.shape[-2:]
        print(f"Raw heatmap resolution: {h_raw}x{w_raw}")

        # === Ground truth ===
        ground_truth_label = get_ground_truth(img_name, input_folder)
        ground_truth_class = class_names.index(ground_truth_label)

        # === Escolher cor frame ===
        frame_color = (0, 255, 0) #green
        if prediction != ground_truth_class:
            frame_color = (0, 0, 255)   #red
    

        # === Overlay do Grad-CAM ===
        overlay = overlay_heatmap(original_np, grayscale_cam[np.newaxis, ...])  # adiciona dimensão extra
        overlay_with_frame = add_colored_frame(overlay, frame_color, thickness=7)

        save_path = os.path.join(output_folder, f"heatmap_{class_names[prediction]}_{img_name}")
        cv2.imwrite(save_path, overlay_with_frame)
        print(f"Saved: {save_path} ; Predicted: {class_names[prediction]}")

        # === Grid de resultados ===
        overlay_rgb = cv2.cvtColor(overlay_with_frame, cv2.COLOR_BGR2RGB)
        overlay_pil = Image.fromarray(overlay_rgb).resize(grid_image_size)
        tensor_for_grid = TF.to_tensor(overlay_pil)

        if prediction == ground_truth_class:
            correctly_classified_tensors.append(tensor_for_grid)
            correct_heatmaps.append(grayscale_cam)  # já está com shape [H, W]
        else:
            misclassified_tensors.append(tensor_for_grid)
            incorrect_heatmaps.append(grayscale_cam)

    # === Geração do Grid ===
    final_sorted_grid = misclassified_tensors + correctly_classified_tensors
    if final_sorted_grid:
        grid = vutils.make_grid(final_sorted_grid, nrow=20, padding=5, normalize=True)
        grid_path = os.path.join(output_folder, "grid_overlay_ordered.jpg")
        vutils.save_image(grid, grid_path)
        print(f"Grid saved at: {grid_path}")

    # === Heatmaps Médios (acertos) ===
    if correct_heatmaps:
        mean_heatmap = np.mean(np.stack(correct_heatmaps), axis=0)
        mean_heatmap -= mean_heatmap.min()
        mean_heatmap /= (mean_heatmap.max() + 1e-8)
        heatmap_uint8 = np.uint8(255 * mean_heatmap)
        heatmap_colored = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)

        h, w = original_images[0].shape[:2]
        heatmap_resized_blocky = cv2.resize(heatmap_colored, (w, h), interpolation=cv2.INTER_NEAREST)
        heatmap_resized_smooth = cv2.resize(heatmap_colored, (w, h), interpolation=cv2.INTER_CUBIC)

        mean_path_blocky = os.path.join(output_folder, "correct_mean_heatmap_blocky.png")
        cv2.imwrite(mean_path_blocky, heatmap_resized_blocky)
        print(f"Mean heatmap (correct only) saved at: {mean_path_blocky}")

        mean_path_smooth = os.path.join(output_folder, "correct_mean_smooth.png")
        cv2.imwrite(mean_path_smooth, heatmap_resized_smooth)
        print(f"Mean heatmap (correct only) saved at: {mean_path_smooth}")

    # === Heatmaps Médios (erros) ===
    if incorrect_heatmaps:
        mean_heatmap_incorrect = np.mean(np.stack(incorrect_heatmaps), axis=0)
        mean_heatmap_incorrect -= mean_heatmap_incorrect.min()
        mean_heatmap_incorrect /= (mean_heatmap_incorrect.max() + 1e-8)
        heatmap_uint8_incorrect = np.uint8(255 * mean_heatmap_incorrect)
        heatmap_colored_incorrect = cv2.applyColorMap(heatmap_uint8_incorrect, cv2.COLORMAP_JET)

        h, w = original_images[0].shape[:2]
        heatmap_resized_blocky_incorrect = cv2.resize(heatmap_colored_incorrect, (w, h), interpolation=cv2.INTER_NEAREST)
        heatmap_resized_smooth_incorrect = cv2.resize(heatmap_colored_incorrect, (w, h), interpolation=cv2.INTER_CUBIC)

        mean_path_blocky_incorrect = os.path.join(output_folder, "incorrect_mean_heatmap_blocky.png")
        cv2.imwrite(mean_path_blocky_incorrect, heatmap_resized_blocky_incorrect)
        print(f"Mean heatmap (incorrect only) saved at: {mean_path_blocky_incorrect}")

        mean_path_smooth_incorrect = os.path.join(output_folder, "incorrect_mean_smooth.png")
        cv2.imwrite(mean_path_smooth_incorrect, heatmap_resized_smooth_incorrect)
        print(f"Mean heatmap (incorrect only) saved at: {mean_path_smooth_incorrect}")

    return correct_heatmaps, original_images

# %%
"""def generate_prediction_table_only(model, input_folder, split_name, structure, birth_type, dataset):
    transform = transforms.Compose([
        transforms.Grayscale(num_output_channels=1),  # Convert to grayscale
        transforms.Resize((80,80)),  # Match model's input size
        transforms.ToTensor(),
    ])

    class_names = ["Cesarean Birth", "Vaginal Birth"]
    prediction_results = []

    for img_name in os.listdir(input_folder):
        if not img_name.lower().endswith(".png"):
            continue

        img_path = os.path.join(input_folder, img_name)
        image = Image.open(img_path).convert("RGB")
        input_tensor = transform(image).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(input_tensor)
            prediction = output.argmax(dim=1).item()
            probabilities = torch.softmax(output, dim=1)
            confidence = probabilities[0, prediction].item()

        ground_truth_label = get_ground_truth(img_name, input_folder)
        ground_truth_class = class_names.index(ground_truth_label)

        prediction_results.append({
            "Image": img_name,
            "Predicted Class": class_names[prediction],
            "Ground Truth": ground_truth_label,
            "Correct": prediction == ground_truth_class,
            "Confidence": round(confidence, 4),
            "Split": split_name,
            "Structure": structure,
            "Birth Type": birth_type,
            "Dataset": dataset
        })

    return pd.DataFrame(prediction_results)"""
# Out:
# 'def generate_prediction_table_only(model, input_folder, split_name, structure, birth_type, dataset):\n    transform = transforms.Compose([\n        transforms.Grayscale(num_output_channels=1),  # Convert to grayscale\n        transforms.Resize((80,80)),  # Match model\'s input size\n        transforms.ToTensor(),\n    ])\n\n    class_names = ["Cesarean Birth", "Vaginal Birth"]\n    prediction_results = []\n\n    for img_name in os.listdir(input_folder):\n        if not img_name.lower().endswith(".png"):\n            continue\n\n        img_path = os.path.join(input_folder, img_name)\n        image = Image.open(img_path).convert("RGB")\n        input_tensor = transform(image).unsqueeze(0).to(device)\n\n        with torch.no_grad():\n            output = model(input_tensor)\n            prediction = output.argmax(dim=1).item()\n            probabilities = torch.softmax(output, dim=1)\n            confidence = probabilities[0, prediction].item()\n\n        ground_truth_label = get_ground_truth(img_name, input_folder)\n        ground_truth_class = class_names.index(ground_truth_label)\n\n        prediction_results.append({\n            "Image": img_name,\n            "Predicted Class": class_names[prediction],\n            "Ground Truth": ground_truth_label,\n            "Correct": prediction == ground_truth_class,\n            "Confidence": round(confidence, 4),\n            "Split": split_name,\n            "Structure": structure,\n            "Birth Type": birth_type,\n            "Dataset": dataset\n        })\n\n    return pd.DataFrame(prediction_results)'

# %%
def main():

    #only_generate_csv = True

    structures = ["Abdomen_","Femur_", "Head_"] 
    birth_types = ["Cesarean Birth", "Vaginal Birth"]
    datasets = ["test"]#, "test"]
    splits = ["cv3"]#,"cv2","cv3"] 

    base_input = "C:/Users/anale/OneDrive/Documentos/Universidade/TESE/image-dataset/dataset_images_{split}/{structure}/{dataset}/{birth_type}"
    base_output = "C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_{structure_clean}_{birth_type_short}_{dataset}"
    base_weight = "C:/Users/anale/OneDrive/Documentos/Universidade/TESE/model_paths/DenseNet_paths/{structure_clean}_{split}_densenet169_best-model.pth" #best-model_{split}_{structure_clean}_resnet18.pth" 
    #output_dir = "C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/prediction_tables"
    #os.makedirs(output_dir, exist_ok=True)

    #excel_save_path = "C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/predictions_confidence_resnet18.xlsx"

    #if only_generate_csv:
    #    dfs_by_split = {split: [] for split in splits}
        
    for split in splits:
        for structure in structures:
            structure_clean = structure.rstrip("_").lower()
            for birth_type in birth_types:
                birth_type_short = birth_type.split()[0].lower()  # 'cesarean' or 'vaginal'
                for dataset in datasets:
                    input_folder = base_input.format(split=split, structure=structure, birth_type=birth_type, dataset=dataset)
                    output_folder = base_output.format(split=split, structure_clean=structure_clean, birth_type_short=birth_type_short, dataset=dataset)
                    weight_path = base_weight.format(structure_clean=structure_clean, split=split)

                    if not os.path.exists(weight_path):
                        print(f"[SKIPPED] Weight file does not exist: {weight_path}")
                        continue

                    print(f"Processing: {structure}, {birth_type}, {dataset}, {split}")
                    model = load_densenet169_model(weight_path, num_classes=2)
                    all_heatmaps, original_images = apply_gradcam_and_save(model, input_folder, output_folder)

                    """df = generate_prediction_table_only(
                        model, 
                        input_folder, 
                        split_name=split,
                        structure=structure_clean,
                        birth_type=birth_type_short,
                        dataset=dataset
                    )
                    dfs_by_split[split].append(df)
                    
        # === GUARDAR CSVs ===
        for split, df_list in dfs_by_split.items():
            if df_list:
                combined_df = pd.concat(df_list, ignore_index=True)
                csv_path = os.path.join(output_dir, f"{split}.csv")
                combined_df.to_csv(csv_path, index=False)
                print(f"Guardado: {csv_path}")

    else:
        print("Pipeline completo (com heatmaps) não ativado. Altere `only_generate_csv` para False se necessário.")"""

    print("All Grad-CAM heatmaps were generated successfully.")

if __name__ == "__main__":
    main()
# Out:
# Processing: Abdomen_, Cesarean Birth, test, cv3
# C:\Users\anale\AppData\Local\Temp\ipykernel_2200\354849709.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU10002107_abdomen1_276.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU10008343_abdomen1_278.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU10011068_abdomen1_467.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU10014002_abdomen1_3.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU10022513_abdomen1_1.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU10022616_abdomen1_211.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU10025847_abdomen1_806.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU1003661_abdomen1_6.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU11004693_abdomen1_640.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU11005271_abdomen1_215.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU13022125_abdomen1_231.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU14027930_abdomen1_244.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU15042514_abdomen1_665.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU16001996_abdomen1_57.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU16008331_abdomen1_503.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU16011929_abdomen1_258.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU17009119_abdomen1_68.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU17019799_abdomen1_304.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU17022392_abdomen1_307.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU17022472_abdomen1_669.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU18010924_abdomen1_514.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU18014821_abdomen1_683.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU18020643_abdomen1_698.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU18028734_abdomen1_88.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU18057908_abdomen1_278.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19001718_abdomen1_330.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19007484_abdomen1_542.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19008327_abdomen1_336.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19011423_abdomen1_708.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19014550_abdomen1_520.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19017940_abdomen1_557.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19023224_abdomen1_289.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19025956_abdomen1_719.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19026687_abdomen1_565.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19028420_abdomen1_345.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19029525_abdomen1_722.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19031008_abdomen1_302.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19072745_abdomen1_43.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19093249_abdomen1_322.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19095022_abdomen1_328.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19186554_abdomen1_336.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19318732_abdomen1_355.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19428417_abdomen1_346.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19571021_abdomen1_364.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19740326_abdomen1_350.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19759372_abdomen1_788.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU19900168_abdomen1_82.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU19924151_abdomen1_533.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU2000870_abdomen1_743.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU20010600_abdomen1_131.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU20027451_abdomen1_750.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU20044781_abdomen1_102.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU21001673_abdomen1_392.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU21005405_abdomen1_394.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU21006222_abdomen1_103.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU21008568_abdomen1_395.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9004941_abdomen1_754.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9006259_abdomen1_755.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU9014454_abdomen1_207.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9101141_abdomen1_756.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9111006_abdomen1_762.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9114406_abdomen1_219.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9122053_abdomen1_423.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9122261_abdomen1_768.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU9123107_abdomen1_227.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU9132927_abdomen1_863.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9148482_abdomen1_441.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9149830_abdomen1_454.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9155829_abdomen1_243.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU9156009_abdomen1_161.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9160523_abdomen1_0.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9163002_abdomen1_778.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9164324_abdomen1_472.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9164617_abdomen1_779.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Cesarean Birth_PU9175486_abdomen1_449.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9178397_abdomen1_176.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9190880_abdomen1_452.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9192975_abdomen1_249.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9322841_abdomen1_781.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU9359004_abdomen1_783.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU98013614_abdomen1_463.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\heatmap_Vaginal Birth_PU99011179_abdomen1_632.png ; Predicted: Vaginal Birth
# Grid saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\grid_overlay_ordered.jpg
# Mean heatmap (correct only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\correct_mean_heatmap_blocky.png
# Mean heatmap (correct only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\correct_mean_smooth.png
# Mean heatmap (incorrect only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\incorrect_mean_heatmap_blocky.png
# Mean heatmap (incorrect only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_cesarean_test\incorrect_mean_smooth.png
# Processing: Abdomen_, Vaginal Birth, test, cv3
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU10012069_abdomen1_207.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU10016707_abdomen1_4.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU1009041_abdomen1_5.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU10133_abdomen1_8.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11001994_abdomen1_471.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11003774_abdomen1_10.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11010269_abdomen1_473.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11011375_abdomen1_641.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11011500_abdomen1_12.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11011922_abdomen1_14.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11015461_abdomen1_283.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11018741_abdomen1_807.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU11023244_abdomen1_11.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU12001297_abdomen1_475.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU12005094_abdomen1_525.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU12019377_abdomen1_476.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU12024821_abdomen1_645.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13003334_abdomen1_647.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13010108_abdomen1_21.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13012884_abdomen1_32.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13017234_abdomen1_648.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13019253_abdomen1_478.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU13020999_abdomen1_652.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU14000036_abdomen1_34.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU14000225_abdomen1_656.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU14004343_abdomen1_239.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU14011083_abdomen1_659.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU14014745_abdomen1_545.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU14022997_abdomen1_660.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15025198_abdomen1_245.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU15036363_abdomen1_248.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15044432_abdomen1_29.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15044788_abdomen1_497.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15044789_abdomen1_54.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU15052143_abdomen1_666.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15052145_abdomen1_819.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU15054164_abdomen1_791.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU16000751_abdomen1_56.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU16001123_abdomen1_249.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU16005375_abdomen1_251.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU16006066_abdomen1_60.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU16016449_abdomen1_294.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU17010966_abdomen1_262.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU17018177_abdomen1_34.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU17023684_abdomen1_70.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU17024105_abdomen1_821.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18000400_abdomen1_37.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18006563_abdomen1_673.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18009559_abdomen1_76.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18014441_abdomen1_679.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18020113_abdomen1_314.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18020313_abdomen1_693.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18020527_abdomen1_524.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18021022_abdomen1_39.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18021586_abdomen1_526.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18024025_abdomen1_321.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU18027890_abdomen1_271.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU18027934_abdomen1_322.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU18125400_abdomen1_100.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19003392_abdomen1_823.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19006214_abdomen1_707.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19008690_abdomen1_545.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19011271_abdomen1_549.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19011455_abdomen1_550.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU19016207_abdomen1_553.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19016404_abdomen1_556.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Cesarean Birth_PU19021703_abdomen1_561.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19021995_abdomen1_288.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19026447_abdomen1_104.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19028035_abdomen1_298.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19028838_abdomen1_721.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19031538_abdomen1_304.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19031646_abdomen1_105.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19032886_abdomen1_723.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19034343_abdomen1_106.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19035185_abdomen1_107.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19036569_abdomen1_313.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19079854_abdomen1_317.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19185786_abdomen1_725.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19205574_abdomen1_727.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19235064_abdomen1_353.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19235503_abdomen1_728.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_abdomen_vaginal_test\heatmap_Vaginal Birth_PU19264301_abdomen1_730.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# ...
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9113806_head1_1.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9115676_head1_106.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9118301_head1_564.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9118476_head1_493.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9118931_head1_400.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9121929_head1_208.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9123582_head1_495.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9123969_head1_403.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9124525_head1_209.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9125394_head1_211.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9126835_head1_496.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9127210_head1_305.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9128899_head1_703.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9132981_head1_308.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9135114_head1_310.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9135122_head1_497.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9135947_head1_498.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9137701_head1_707.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9140786_head1_3.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9143145_head1_117.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9150298_head1_215.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9154576_head1_511.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9155422_head1_715.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9165981_head1_218.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9176559_head1_725.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9177573_head1_764.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9178681_head1_313.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9183838_head1_121.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9186514_head1_729.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9189288_head1_733.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9210236_head1_525.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9213106_head1_754.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9214144_head1_738.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9214316_head1_316.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Cesarean Birth_PU9215473_head1_317.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9313454_head1_224.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9330652_head1_570.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9338271_head1_124.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9345351_head1_742.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9345636_head1_320.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9346762_head1_571.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9366599_head1_322.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9380363_head1_324.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9381492_head1_743.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9391673_head1_744.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU9399308_head1_746.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Cesarean Birth_PU95009725_head1_774.png ; Predicted: Cesarean Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU97008513_head1_775.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU97016842_head1_573.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU97017462_head1_127.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU97024436_head1_132.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU98001875_head1_749.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU98007875_head1_778.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU98009741_head1_133.png ; Predicted: Vaginal Birth
# RAW FEATURE MAP SHAPE: torch.Size([1, 32, 5, 5])
# Raw heatmap resolution: 5x5
# Saved: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\heatmap_Vaginal Birth_PU99012515_head1_327.png ; Predicted: Vaginal Birth
# Grid saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\grid_overlay_ordered.jpg
# Mean heatmap (correct only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\correct_mean_heatmap_blocky.png
# Mean heatmap (correct only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\correct_mean_smooth.png
# Mean heatmap (incorrect only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\incorrect_mean_heatmap_blocky.png
# Mean heatmap (incorrect only) saved at: C:/Users/anale/OneDrive/Documentos/Universidade/TESE/RESULTS/PlusPlus_denseblock3/grad_densenet_head_vaginal_test\incorrect_mean_smooth.png
# All Grad-CAM heatmaps were generated successfully.
